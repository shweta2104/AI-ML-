# %%
#Que 1

def Add():
    X = 10 + 20
    print(X)
Add()
# Out:
# 30

# %%
#Que 2
def Add(X,Y):
    Z = X+Y
    print(Z)

# %%
Add(20,10)
# Out:
# 30

# %%
#Que 3

def Add(X,Y):
    Z = X+Y
    return Z
    C=Add(20,10)
    print("Total =",C)

# %%
#que 4

def Check(num): #Line 1
if num%2==0: #Line 2
print("Hello") #Line 3
return True #Line 4
print("Bye") #Line 5
else: #Line 6
return False #Line 7
C = Check(20)
print(C)


#Ans : print("Bye")  # Line 5
# Once return is executed, the function exits immediately, so any code after it inside the same block will never run.
#Therefore, print("Bye") is unreachable.

# %%
#que 5

def Cube(n):
    print(n*n*n)
    Cube(n)  # n is 10 here
    print(Cube(n))

#Ans: Error because value of nn is not defined 

#corrected code\
'''
def Cube(n):
    print(n*n*n)

n = 10
Cube(n)
print(Cube(n))
'''
# Out:
# 1000
# 1000
# None

# %%
#que 6
'''
Ravi a python programmer is working on a project, for some requirement, he has
to define a function with name CalculateInterest(), he defined it as:
def CalculateInterest(Principal,Rate=.06,Time):
# code
But this code is not working, Can you help Ravi to identify the error in theabove function and what is the solution.'''

#Error:
'''
-> In Python, all default parameters must come after non-default parameters.
-> Here, Rate has a default value (.06), but Time does not.
-> Python will raise a SyntaxError:
        non-default argument follows default argument'''

#Solution:

#Give all parameters default values
def CalculateInterest(Principal=0, Rate=0.06, Time=1):
    # code
# Out:
#   Cell In[21], line 20
#     # code
#           ^
# _IncompleteInputError: incomplete input

# %%
#que 7

#Call the given function using KEYWORD ARGUMENT with values 100 and 200 
def Swap(num1,num2): 
    num1,num2=num2,num1 
    print(num1,num2) 
    
Swap(num1=100,num2=200)
# Out:
# 200 100

# %%
#que 8

Which line number of code(s) will not work and why? 
def Interest(P,R,T=7): 
    I = (P*R*T)/100 print(I) 
Interest(20000,.08,15)

Line 2: Positional argument after keyword argument.

Line 4: Incorrect keyword Time instead of T.

Line 5: Missing required positional argument R.
